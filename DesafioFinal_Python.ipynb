# %% [markdown]
# # Importando e lendo os dados

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dr =  pd.read_csv('/content/dados_rh.csv')
dr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
dr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
dr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Nesta base de dados temos 8 linhas e 26 colunas, não existem dados nulos, tendo em vista que a soma de dados nulos deu zero, alguns dos tipos de dados são, booleanos como em employeeCount, String em Education Field, Inteiro em idade e float em distance from home.

# %% [markdown]
# # Plote um gráfico de barras (bar) que exiba a quantidade de funcionários em cada setor (coluna Department)

# %%
drQf = dr.groupby('Department')[['EmployeeCount']].count()

# %%
drQf.plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %% [markdown]
# # Plote um gráfico de linha (line) que exiba a quantidade de funcionários para cada nível de escolaridade (coluna Education)

# %%
drQfEsc = dr.groupby('Education')[['EmployeeCount']]
drQfEsc.count()
# Out:
#            EmployeeCount
# Education
# 1                    170
# 2                    282
# 3                    572
# 4                    398
# 5                     48

# %%
drQf.count().plot(kind='line')
# Out:
# <Axes: xlabel='Education'>

# %% [markdown]
# # Plote um gráfico de torta/pizza (pie) que exiba a quantidade de funcionários que tem ou não algum atrito na empresa (coluna Attrition).

# %%
drQfAt = dr.groupby('Attrition')[['EmployeeCount']]
drQfAt.count()
# Out:
#            EmployeeCount
# Attrition
# No                  1233
# Yes                  237

# %%
drQfAt.count().plot(kind='pie', subplots=True)
# Out:
# array([<Axes: ylabel='EmployeeCount'>], dtype=object)
